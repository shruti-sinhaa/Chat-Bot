# %% [markdown]
# <a href="https://colab.research.google.com/github/shruti-sinhaa/Chat-Bot/blob/main/chat_bot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  Description : This is a chat box program

# %%
#import the library
from nltk.chat.util import Chat, reflections

# %%
pairs = [
    ['my name is (.*)', ['hi %1']]
]

# %%
reflections
# Out:
# {'i am': 'you are',
#  'i was': 'you were',
#  'i': 'you',
#  "i'm": 'you are',
#  "i'd": 'you would',
#  "i've": 'you have',
#  "i'll": 'you will',
#  'my': 'your',
#  'you are': 'I am',
#  'you were': 'I was',
#  "you've": 'I have',
#  "you'll": 'I will',
#  'your': 'my',
#  'yours': 'mine',
#  'you': 'me',
#  'me': 'you'}

# %%
chat = Chat(pairs, reflections)
chat.converse()
# Out:
# >my name is pina
# hi pina
# >my name is shruti
# hi shruti
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_567/323297157.py in <cell line: 0>()
#       1 chat = Chat(pairs, reflections)
# ----> 2 chat.converse()
#
# /usr/local/lib/python3.12/dist-packages/nltk/chat/util.py in converse(self, quit)
#     116             user_input = quit
#     117             try:
# --> 118                 user_input = input(">")
#     119             except EOFError:
#     120                 print(user_input)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# ...
